# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pylab
import matplotlib.pyplot as plt
from matplotlib.pylab import rcParams

# %%
pwd
# Out:
# '/Users/janhavi'

# %%
df = pd.read_csv('/Users/janhavi/Desktop/dataset.csv')
df.head(25)
# Out:
#    CountryName CountryCode                                      IndicatorName  \
# 0   Arab World         ARB  Adolescent fertility rate (births per 1,000 wo...
# 1   Arab World         ARB  Age dependency ratio (% of working-age populat...
# 2   Arab World         ARB  Age dependency ratio, old (% of working-age po...
# 3   Arab World         ARB  Age dependency ratio, young (% of working-age ...
# 4   Arab World         ARB               Aquaculture production (metric tons)
# 5   Arab World         ARB        Arms exports (SIPRI trend indicator values)
# 6   Arab World         ARB        Arms imports (SIPRI trend indicator values)
# 7   Arab World         ARB               Birth rate, crude (per 1,000 people)
# 8   Arab World         ARB                             Broad money (% of GDP)
# 9   Arab World         ARB         Capture fisheries production (metric tons)
# 10  Arab World         ARB         Claims on central government, etc. (% GDP)
# ...

# %%
df = df[~df['IndicatorName'].astype(str).str.startswith('A')]
df = df[~df['IndicatorName'].astype(str).str.startswith('B')]
df = df[~df['IndicatorName'].astype(str).str.startswith('Ca')]
df = df[~df['IndicatorName'].astype(str).str.startswith('Cla')]
df = df[~df['IndicatorName'].astype(str).str.startswith('D')]
df = df[~df['IndicatorName'].astype(str).str.startswith('F')]
df = df[~df['IndicatorName'].astype(str).str.startswith('G')]
df = df[~df['IndicatorName'].astype(str).str.startswith('H')]
df = df[~df['IndicatorName'].astype(str).str.startswith('I')]
df = df[~df['IndicatorName'].astype(str).str.startswith('L')]
df = df[~df['IndicatorName'].astype(str).str.startswith('M')]
df = df[~df['IndicatorName'].astype(str).str.startswith('N')]
df = df[~df['IndicatorName'].astype(str).str.startswith('P')]
df = df[~df['IndicatorName'].astype(str).str.startswith('R')]
df = df[~df['IndicatorName'].astype(str).str.startswith('S')]
df = df[~df['IndicatorName'].astype(str).str.startswith('T')]
df = df[~df['IndicatorName'].astype(str).str.startswith('U')]

# %%
df.head(30)

# %%
search = 'CO'
series = df['IndicatorName'].str.startswith(search, na = False)
df[series]
# Out:
#         CountryName CountryCode  \
# 11       Arab World         ARB
# 12       Arab World         ARB
# 13       Arab World         ARB
# 14       Arab World         ARB
# 15       Arab World         ARB
# ...             ...         ...
# 7099664    Zimbabwe         ZWE
# 7099665    Zimbabwe         ZWE
# 7099666    Zimbabwe         ZWE
# 7099667    Zimbabwe         ZWE
# 7099668    Zimbabwe         ZWE
#
#                                              IndicatorName      IndicatorCode  \
# 11                                      CO2 emissions (kt)     EN.ATM.CO2E.KT
# 12                  CO2 emissions (metric tons per capita)     EN.ATM.CO2E.PC
# 13       CO2 emissions from gaseous fuel consumption (%...  EN.ATM.CO2E.GF.ZS
# 14       CO2 emissions from liquid fuel consumption (% ...  EN.ATM.CO2E.LF.ZS
# 15         CO2 emissions from liquid fuel consumption (kt)  EN.ATM.CO2E.LF.KT
# ...                                                    ...                ...
# ...
